# %%
from IPython.display import Image, display
from pathlib import Path

RUN_DIR = Path("../../runs/three_country_training/road_defect_binary/yolov26s2")

display(Image(filename=str(RUN_DIR / "results.png")))
display(Image(filename=str(RUN_DIR / "confusion_matrix.png")))

# %%
import pandas as pd

results_csv = RUN_DIR / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 65     66   9623.04         1.61993         1.33204         0.01535
# 66     67   9766.77         1.62313         1.32029         0.01535
# 67     68   9910.59         1.61725         1.31991         0.01534
# 68     69  10054.10         1.61060         1.30703         0.01514
# 69     70  10197.90         1.60419         1.29961         0.01501
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 65               0.64572            0.54970           0.60056
# 66               0.64259            0.55335           0.60067
# 67               0.64209            0.55160           0.60030
# 68               0.64201            0.55335           0.59995
# 69               0.64534            0.55224           0.59969
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 65              0.30062       1.78871       1.51391       0.01800  0.002421
# 66              0.30008       1.79219       1.51428       0.01806  0.001997
# 67              0.30030       1.79214       1.51910       0.01809  0.001573
# 68              0.29954       1.79637       1.51739       0.01815  0.001149
# 69              0.29912       1.80010       1.51563       0.01820  0.000724
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 65  0.000807  0.002421  0.000807  0.002421  0.000807  0.002421  0.000807
# 66  0.000666  0.001997  0.000666  0.001997  0.000666  0.001997  0.000666
# 67  0.000524  0.001573  0.000524  0.001573  0.000524  0.001573  0.000524
# 68  0.000383  0.001149  0.000383  0.001149  0.000383  0.001149  0.000383
# 69  0.000241  0.000724  0.000241  0.000724  0.000241  0.000724  0.000241

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")
# Out:
# Final metrics:
# Precision: 0.6453
# Recall:    0.5522
# mAP@0.5:   0.5997
# mAP@0.5:0.95: 0.2991
